# %%
from model import UDKCONV
import torch

# %%
UDKCONV_model = UDKCONV()
UDKCONV_model.load_state_dict(torch.load('models/UDKCONV_model.pth'))
UDKCONV_model.eval()
# Out:
# UDKCONV(
#   (C1): KAN_Convolutional_Layer(
#     (convs): ModuleList(
#       (0-15): 16 x KAN_Convolution(
#         (conv): KANLinear(
#           (base_activation): SiLU()
#         )
#       )
#     )
#   )
#   (D1): DownSampling(
#     (Down): Sequential(
#       (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (C2): KAN_Convolutional_Layer(
#     (convs): ModuleList(
#       (0-1): 2 x KAN_Convolution(
#         (conv): KANLinear(
#           (base_activation): SiLU()
#         )
#       )
#     )
#   )
#   (D2): DownSampling(
#     (Down): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (C3): KAN_Convolutional_Layer(
#     (convs): ModuleList(
#       (0-1): 2 x KAN_Convolution(
#         (conv): KANLinear(
#           (base_activation): SiLU()
#         )
#       )
#     )
#   )
# ...

# %%
import numpy as np

# %%
def trans_freq_dom(image):
    image_dft = np.fft.fftshift(np.fft.fft2(image))
    image_dft_log = np.log(np.abs(image_dft))
    return image_dft_log

# %%
from loader import train_dataset, test_dataset, valid_dataset
from torch.utils.data import DataLoader
from matplotlib import pyplot as plt

# %%
image, mask = train_dataset[1]

fig, ax = plt.subplots(1, 2)

ax[0].imshow(image.numpy().squeeze(), cmap='gray')
ax[0].axis('off')
ax[1].imshow(mask.numpy().squeeze(), cmap='gray')
ax[1].axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %%
fig, ax = plt.subplots(1, 2)

ax[0].imshow(trans_freq_dom(image.numpy().squeeze()), cmap='gray')
ax[0].axis('off')
ax[1].imshow(trans_freq_dom(mask.numpy().squeeze()), cmap='gray')
ax[1].axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %%
R1, R2, R3, R4, Y1, O1, O2, O3, O4, Y2 = UDKCONV_model.visualize(image.reshape(1,1,128,128))

# %%
R1.shape
# Out:
# torch.Size([1, 16, 128, 128])

# %%
n_x, n_y = 4, 4

figure, ax = plt.subplots(n_x, n_y)

for i in range(n_x):
    for j in range(n_y):
        ax[i, j].imshow(R1[0, i*n_y+j, :, :].detach().numpy().squeeze(), cmap='gray')
        ax[i, j].axis('off')
plt.tight_layout()

# %%
n_x, n_y = 4, 4

figure, ax = plt.subplots(n_x, n_y)

for i in range(n_x):
    for j in range(n_y):
        ax[i, j].imshow(trans_freq_dom(R1[0, i*n_y+j, :, :].detach().numpy().squeeze()), cmap='gray')
        ax[i, j].axis('off')
plt.tight_layout()

# %%
R2.shape
# Out:
# torch.Size([1, 32, 64, 64])

# %%
n_x, n_y = 4, 8

figure, ax = plt.subplots(n_x, n_y)

for i in range(n_x):
    for j in range(n_y):
        ax[i, j].imshow(R2[0, i*n_y+j, :, :].detach().numpy().squeeze(), cmap='gray')
        ax[i, j].axis('off')
plt.tight_layout()

# %%
n_x, n_y = 4, 8

figure, ax = plt.subplots(n_x, n_y)

for i in range(n_x):
    for j in range(n_y):
        ax[i, j].imshow(trans_freq_dom(R2[0, i*n_y+j, :, :].detach().numpy().squeeze()), cmap='gray')
        ax[i, j].axis('off')
plt.tight_layout()

# %%
R3.shape
# Out:
# torch.Size([1, 64, 32, 32])

# %%
n_x, n_y = 8, 8

figure, ax = plt.subplots(n_x, n_y)

for i in range(n_x):
    for j in range(n_y):
        ax[i, j].imshow(R3[0, i*n_y+j, :, :].detach().numpy().squeeze(), cmap='gray')
        ax[i, j].axis('off')
plt.tight_layout()

# %%
n_x, n_y = 8, 8

figure, ax = plt.subplots(n_x, n_y)

for i in range(n_x):
    for j in range(n_y):
        ax[i, j].imshow(trans_freq_dom(R3[0, i*n_y+j, :, :].detach().numpy().squeeze()), cmap='gray')
        ax[i, j].axis('off')
plt.tight_layout()

# %%
R4.shape
# Out:
# torch.Size([1, 128, 16, 16])

# %%
n_x, n_y = 8, 16

figure, ax = plt.subplots(n_x, n_y)

for i in range(n_x):
    for j in range(n_y):
        ax[i, j].imshow(R4[0, i*n_y+j, :, :].detach().numpy().squeeze(), cmap='gray')
        ax[i, j].axis('off')
plt.tight_layout()

# %%
n_x, n_y = 8, 16

figure, ax = plt.subplots(n_x, n_y)

for i in range(n_x):
    for j in range(n_y):
        ax[i, j].imshow(trans_freq_dom(R4[0, i*n_y+j, :, :].detach().numpy().squeeze()), cmap='gray')
        ax[i, j].axis('off')
plt.tight_layout()

# %%
Y1.shape
# Out:
# torch.Size([1, 256, 8, 8])

# %%
n_x, n_y = 16, 16

figure, ax = plt.subplots(n_x, n_y)

for i in range(n_x):
    for j in range(n_y):
        ax[i, j].imshow(Y1[0, i*n_y+j, :, :].detach().numpy().squeeze(), cmap='gray')
        ax[i, j].axis('off')
plt.tight_layout()

# %%
n_x, n_y = 16, 16

figure, ax = plt.subplots(n_x, n_y)

for i in range(n_x):
    for j in range(n_y):
        ax[i, j].imshow(trans_freq_dom(Y1[0, i*n_y+j, :, :].detach().numpy().squeeze()), cmap='gray')
        ax[i, j].axis('off')
plt.tight_layout()

# %%
O1.shape
# Out:
# torch.Size([1, 128, 16, 16])

# %%
n_x, n_y = 8, 16

figure, ax = plt.subplots(n_x, n_y)

for i in range(n_x):
    for j in range(n_y):
        ax[i, j].imshow(O1[0, i*n_y+j, :, :].detach().numpy().squeeze(), cmap='gray')
        ax[i, j].axis('off')
plt.tight_layout()

# %%
n_x, n_y = 8, 16

figure, ax = plt.subplots(n_x, n_y)

for i in range(n_x):
    for j in range(n_y):
        ax[i, j].imshow(trans_freq_dom(O1[0, i*n_y+j, :, :].detach().numpy().squeeze()), cmap='gray')
        ax[i, j].axis('off')
plt.tight_layout()

# %%
O2.shape
# Out:
# torch.Size([1, 64, 32, 32])

# %%
n_x, n_y = 8, 8 

figure, ax = plt.subplots(n_x, n_y)

for i in range(n_x):
    for j in range(n_y):
        ax[i, j].imshow(O2[0, i*n_y+j, :, :].detach().numpy().squeeze(), cmap='gray')
        ax[i, j].axis('off')
plt.tight_layout()

# %%
n_x, n_y = 8, 8 

figure, ax = plt.subplots(n_x, n_y)

for i in range(n_x):
    for j in range(n_y):
        ax[i, j].imshow(trans_freq_dom(O2[0, i*n_y+j, :, :].detach().numpy().squeeze()), cmap='gray')
        ax[i, j].axis('off')
plt.tight_layout()

# %%
O3.shape
# Out:
# torch.Size([1, 32, 64, 64])

# %%
n_x, n_y = 4, 8

figure, ax = plt.subplots(n_x, n_y)

for i in range(n_x):
    for j in range(n_y):
        ax[i, j].imshow(O3[0, i*n_y+j, :, :].detach().numpy().squeeze(), cmap='gray')
        ax[i, j].axis('off')
plt.tight_layout()

# %%
n_x, n_y = 4, 8

figure, ax = plt.subplots(n_x, n_y)

for i in range(n_x):
    for j in range(n_y):
        ax[i, j].imshow(trans_freq_dom(O3[0, i*n_y+j, :, :].detach().numpy().squeeze()), cmap='gray')
        ax[i, j].axis('off')
plt.tight_layout()

# %%
O4.shape
# Out:
# torch.Size([1, 16, 128, 128])

# %%
n_x, n_y = 4, 4

figure, ax = plt.subplots(n_x, n_y)

for i in range(n_x):
    for j in range(n_y):
        ax[i, j].imshow(O4[0, i*n_y+j, :, :].detach().numpy().squeeze(), cmap='gray')
        ax[i, j].axis('off')
plt.tight_layout()

# %%
n_x, n_y = 4, 4

figure, ax = plt.subplots(n_x, n_y)

for i in range(n_x):
    for j in range(n_y):
        ax[i, j].imshow(trans_freq_dom(O4[0, i*n_y+j, :, :].detach().numpy().squeeze()), cmap='gray')
        ax[i, j].axis('off')
plt.tight_layout()

# %%
Y2.shape
# Out:
# torch.Size([1, 1, 128, 128])

# %%
plt.imshow(Y2[0, 0, :, :].detach().numpy().squeeze(), cmap='gray')
plt.axis('off')
plt.tight_layout()

# %%
plt.imshow(trans_freq_dom(Y2[0, 0, :, :].detach().numpy().squeeze()), cmap='gray')
plt.axis('off')
plt.tight_layout()
